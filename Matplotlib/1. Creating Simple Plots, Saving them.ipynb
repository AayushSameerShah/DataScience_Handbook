# %% [markdown]
# # Simple, Basic

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
space = np.linspace(0,10,10)

# %%
plt.plot(np.cos(space), np.sin(space))

# %% [markdown]
# # `%matplotlib` will make the plots to be opened in the Seperate window.

# %% [markdown]
# # `%matplotlib inilne` lats you to plot `PNG` static pltots as images in the notebook

# %% [markdown]
# # `matplotlib notebook` will let you to plot `interactive` plots in the notebook

# %% [markdown]
# #

# %%
# %matplotlib notebook

# %%
# restarting the kernel

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
space = np.linspace(0,10,100)

# %%
plt.plot(space, np.sin(space))
plt.plot(space, np.cos(space))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### You can show `Images` from IPython module

# %% [markdown]
# # 1. `from IPython.display import Image`
# # 2. `Image('path')`

# %%
fig = plt.figure()
plt.plot(space, np.sin(space))
plt.plot(space, np.cos(space))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.savefig('CHACAH.png')

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(space, np.sin(space))
plt.plot(space, np.cos(space))

# %%
plt.plot(np.linspace(0,5,100), np.sin(space))

# %%
kaka= plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
kaka.savefig('KAKA.jpg')

# %%
fig.savefig('temp')

# %%
fig = plt.figure()
plt.plot(space, np.sin(space))
plt.plot(space, np.cos(space))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Get the Supported saing file types

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
fig.canvas.get_supported_filetypes_grouped()
# Out:
# {'Encapsulated Postscript': ['eps'],
#  'Joint Photographic Experts Group': ['jpeg', 'jpg'],
#  'Portable Document Format': ['pdf'],
#  'PGF code for LaTeX': ['pgf'],
#  'Portable Network Graphics': ['png'],
#  'Postscript': ['ps'],
#  'Raw RGBA bitmap': ['raw', 'rgba'],
#  'Scalable Vector Graphics': ['svg', 'svgz'],
#  'Tagged Image File Format': ['tif', 'tiff']}

# %%
fig.canvas.get_width_height()
# Out:
# (960, 720)
