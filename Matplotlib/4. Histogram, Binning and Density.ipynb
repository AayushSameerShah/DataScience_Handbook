# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# %xmode Minimal
# Out:
# Exception reporting mode: Minimal

# %% [markdown]
# ### Histogram

# %%
x = np.random.randint(0,100,100)

# %%
plt.hist(x)
# Out:
# (array([11.,  5., 16.,  9., 13.,  8.,  8.,  7.,  9., 14.]),
#  array([ 3. , 12.5, 22. , 31.5, 41. , 50.5, 60. , 69.5, 79. , 88.5, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
#     Here ↓, I will use ';' to hide the extra data

# %%
plt.hist(x);

# %% [markdown]
# ###

# %% [markdown]
# ### Taking their example

# %%
x = np.random.randn(100)

# %%
plt.hist(x);

# %% [markdown]
# ### Also note that the default style of the hist is ` histtype= 'stepfilled'`

# %%
plt.hist(x, bins= 30, edgecolor= 'red', color= 'yellow');

# %% [markdown]
# ###

# %% [markdown]
# ###

# %%
# Use this often to visualize the data together
d1 = np.random.randint(1,100,100)
d2 = np.random.randint(50,150,100)
d3 = np.random.randint(-50,50,100)

plt.hist(d1, bins= 20, alpha= 0.5);
plt.hist(d2, bins= 20, alpha= 0.5);
plt.hist(d3, bins= 20, alpha= 0.5);

# %% [markdown]
# ###

# %% [markdown]
# ### 2D histograms ( call it heatmaps? )

# %%
x = np.random.normal(0,100,10000)
y = np.random.normal(0,100,10000)

plt.hist2d(x, y, bins= 100, cmap= 'Blues');
plt.colorbar()

# %% [markdown]
# ### Likewise `Hexbin`

# %%
plt.hexbin(x,y, cmap= 'Blues', gridsize= 20)
plt.colorbar()

# %% [markdown]
# ###

# %% [markdown]
# ### KDE

# %%
xy = np.vstack([x,y])

# %%
from scipy.stats import gaussian_kde

# %%
kde = gaussian_kde(xy)

# %% [markdown]
# #### KDE obj is ready for the `xy` dataset.
# Now, it is like a `groupby` and ready to apply the function for the further exploration.
# _____
# Let's create the data from that KDE

# %%
spacex = np.linspace(-3.5, 3.5, 40)
spacey = np.linspace(-6, 6, 40)

# %%
X, Y = np.meshgrid(spacex, spacey)

# %% [markdown]
#     Here X.ravel() is used -- to flatten the array

# %%
Z = kde.evaluate(np.vstack([X.ravel(), Y.ravel()]))

# %%
plt.imshow(Z.reshape(X.shape),
          origin= 'lower',
          cmap= 'Blues', aspect= 'auto',
          extent= [-3.5,3.5,-6,6])

# %% [markdown]
# ###
